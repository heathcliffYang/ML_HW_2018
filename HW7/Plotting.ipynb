# %%
import csv
import numpy as np
from matplotlib import pyplot as plt

# %%
test = 0
kernel_choose = 2
x = []
y = []
if (test == 1):
    pca_file_name = "PCA_2d/PCA_test.txt"
    data_num = 2500
else:
    pca_file_name = "PCA_2d/PCA_train.txt"
    data_num = 5000
with open(pca_file_name, newline='') as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        x.append(float(row[0]))
        y.append(float(row[1]))

# %%
# cl = []
# with open("T_test.csv", newline='') as csvfile:
#     rows = csv.reader(csvfile)
#     for row in rows:
#         cl.append(int(row[0]))

# %%
color = ['#da2614', '#b7e020', '#f16ce5', '#169fe3', '#2f5cf4']

# %%
## ground-truth
# axes = plt.gca()
# axes.set_title('PCA_test_gt')
# for i in range(len(cl)):
#     plt.scatter(x[i], y[i], c=color[cl[i]-1], marker='.')
# plt.savefig('PCA_test_gt')

# %%
cl = []
file_name = "first_try/ratio_cut_k_" + str(kernel_choose) + "_d_" + str(data_num) + "_g_" + str(gamma) + ".csv"
with open(file_name, newline='') as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        cl.append(int(row[0]))

# %%
axes = plt.gca()
image_file_name = 'PCA_k_'+str(kernel_choose) + "_d_" + str(data_num)
axes.set_title(image_file_name)
for i in range(len(cl)):
    #print(x[i], y[i], cl[i])
    plt.scatter(x[i], y[i], c=color[cl[i]], marker='.')
plt.savefig(image_file_name)

# %%
# Out:
# []
